# %% [markdown]
# **Problem 1**
#
# Data acquisition

# %%
from sklearn import datasets
import pandas as pd

iris = datasets.load_iris()
X = pd.DataFrame(iris.data)
Y = pd.DataFrame(iris.target)

print(X)
print(Y)
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]

# %% [markdown]
# **Problem 2**
#
# Combining data

# %%
df = pd.concat([X, Y], axis=1)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'Species']
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# **Problem 3**
#
# Checking the data

# %%
"""
Display the 4th sample from the beginning and see what each feature is like. (Numerical data or character data, etc.)
"""

# 4th sample
print('4th sample:')
print(df.loc[[4]])
print('-------------------------------------------------------------------------------------')

# column data type
print('Columns data types:')
print(df.dtypes)
print('-------------------------------------------------------------------------------------')

"""
Total number of samples for each label
"""

print('Total number of samples for each label')
print(df.loc[:,"Species"].value_counts())
print('-------------------------------------------------------------------------------------')

"""
Check if there is a missing value in the feature quantity
"""
print('Checking missing data in dataframe:')
print(df.isnull())
print()
print('Checking if EXIST missing data in dataframeL:')
print(df.isnull().values.any())
print('-------------------------------------------------------------------------------------')

"""
Display the mean, standard deviation, and quartiles of the feature values at once
"""
print(df.describe())
# Out:
# 4th sample:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 4           5.0          3.6           1.4          0.2        0
# -------------------------------------------------------------------------------------
# Columns data types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# Species           int64
# dtype: object
# -------------------------------------------------------------------------------------
# Total number of samples for each label
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64
# -------------------------------------------------------------------------------------
# Checking missing data in dataframe:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# ...

# %% [markdown]
# **Problem 4** <br>
#
# **Context** <br>
# The Iris flower data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# This dataset became a typical test case for many statistical classification techniques in machine learning such as support vector machines
#
# **Content** <br>
# The dataset contains a set of 150 records under 5 attributes - Petal Length, Petal Width, Sepal Length, Sepal width and Class(Species).

# %% [markdown]
# **Problem 5**
#
# Extracting the required data

# %%
"""
Problem 5
Extracting the required data
"""

# Extract sepal_width columns in three different ways
print('\n=============================================================================')
print("Extract sepal_width columns in three different ways")
sepal_width = df.loc[:, 'sepal_width']
print(sepal_width)
sepal_width = df['sepal_width']
print(sepal_width)
sepal_width = df.sepal_width
print(sepal_width)

# Extract the 50th to 99th data
print('\n=============================================================================')
print("50th to 99th data")
data = df.iloc[50:100]
print(data)

# Extract the 50th to 99th data of the petal_length column
print('\n=============================================================================')
print("Extract the 50th to 99th data of the petal_length column")
data = df.loc[50:99,'petal_length']
print(data)

# Extract data with a petal_width value of 0.2
print('\n=============================================================================')
print("Extract data with a petal_width value of 0.2")
data = df.loc[df['petal_width']==0.2]
print(data)
# Out:
# ...
# Extract sepal_width columns in three different ways
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
#
# ...
# 50th to 99th data
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# ...

# %% [markdown]
# **loc** is label-based, which means that you have to specify rows and columns based on their row and column labels. **loc** can also accept boolean data.
#
# **iloc** is integer index based, so you have to specify rows and columns by their integer index.

# %% [markdown]
# **Problem 6**
#
# Creating a diagram

# %%
"""
Problem 6
"""

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = df.groupby("Species")['sepal_length'].count()

labels = iris.target_names
plt.pie(x=data, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title("Number of samples per label", fontsize=14)
plt.show()

# %%
"""
Select features one by one and visualize the distribution of data for each label using a box plot
"""

print('Select features one by one and visualize the distribution of data for each label using a box plot')
def drawBoxPlot(data, title):
    fig, axs = plt.subplots(2, 2)
    axs[0, 0].set_title('Sepal length')
    axs[0, 0].boxplot(data.iloc[:, 0])

    axs[0, 1].set_title('Sepal width')
    axs[0, 1].boxplot(data.iloc[:, 1])

    axs[1, 0].set_title('Petal length')
    axs[1, 0].boxplot(data.iloc[:, 2])

    axs[1, 1].set_title('Petal width')
    axs[1, 1].boxplot(data.iloc[:, 3])

    plt.tight_layout()
    fig.suptitle(title)
    plt.show()

setosa = df.loc[df['Species'] == 0]
versicolor = df.loc[df['Species'] == 1]
virginica = df.loc[df['Species'] == 2]

drawBoxPlot(setosa, 'Setosa')
drawBoxPlot(versicolor, 'Versicolor')
drawBoxPlot(virginica, 'Virginica')
# Out:
# Select features one by one and visualize the distribution of data for each label using a box plot

# %%
"""
Select features one by one and visualize the distribution of data for each label using a violin plot
"""

print('Select features one by one and visualize the distribution of data for each label using a violin plot')
def drawViolinPlot(data, title):
    fig, axs = plt.subplots(2, 2)

    axs[0,0].set_title('Sepal length')
    axs[0,0].violinplot(data.iloc[:, 0])

    axs[0,1].set_title('Sepal width')
    axs[0,1].violinplot(data.iloc[:, 1])

    axs[1,0].set_title('Petal length')
    axs[1,0].violinplot(data.iloc[:, 2])

    axs[1,1].set_title('Petal width')
    axs[1,1].violinplot(data.iloc[:, 3])

    plt.tight_layout()
    fig.suptitle(title)
    plt.show()

drawViolinPlot(setosa, 'Setosa')
drawViolinPlot(versicolor, 'Versicolor')
drawViolinPlot(virginica, 'Virginica')
# Out:
# Select features one by one and visualize the distribution of data for each label using a violin plot

# %% [markdown]
# A **violin plot** is more informative than a plain **box plot**.
#
# While a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data.

# %% [markdown]
# **Problem 7**
#
# Confirming the relationship between features

# %%
"""
Take one feature for each of the vertical and horizontal axes and create a color-coded scatter plot for each type
"""

def drawScatter(data, title):
    fig, axs = plt.subplots(1, 2)

    petal_length = data.loc[:, 'petal_length']
    petal_width = data.loc[:, 'petal_width']
    sepal_length = data.loc[:, 'sepal_length']
    sepal_width = data.loc[:, 'sepal_width']

    axs[0].set_title('Petal')
    axs[0].scatter(petal_length, petal_width)
    axs[0].set(xlabel='Length', ylabel='Width')

    axs[1].set_title('Sepal')
    axs[1].scatter(sepal_length, sepal_width)
    axs[1].set(xlabel='Length', ylabel='Width')

    plt.tight_layout()
    fig.suptitle(title)
    plt.show()

# Take one feature for each of the vertical and horizontal axes and create a color-coded scatter plot for each type (6).
drawScatter(setosa, 'Setosa')
drawScatter(versicolor, 'Versicolor')
drawScatter(virginica, 'Virginica')

# %%
"""
すべての組み合わせの散布図を一度に表示させる、散布図行列を作る
"""

sns.set_theme(style="ticks")
pairplot = sns.pairplot(df, hue="Species")

# %%
"""
Create a correlation coefficient matrix for 4 features
"""
corr = df.iloc[:, 0:4].corr(method='pearson')
print(corr)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
"""
Make a heat map of the correlation coefficient matrix
"""

heatmap = sns.heatmap(data=corr)

# %% [markdown]
# **Problem 8**
#
# Explaining the results of visualized graphs and tables
#
# Looking at the violin plot, we can see that
# - the sepal width, length and petal pental length of Setosa follows a normal distribution.
# - the distributions of 4 features of Versicolor are more skewed and have higher variance.
# - the distributions of 4 features of Virginia do not follow a normal distributions, but still have high frequency of data at the center.
#
# Looking at the heat map:
# - There is a significant correlation between sepal length and petal length, petal_width. Sepal length and sepal width don't have any correlation.
# - Sepal width seems to have no correlation with any features.
# - Petal length and width seems to have high correlation.
